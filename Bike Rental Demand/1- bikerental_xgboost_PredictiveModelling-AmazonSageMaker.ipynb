# %% [markdown]
# ## Train a model with bike rental data using XGBoost algorithm
# ###  Model is trained with SageMaker's XGBoost algorithm

# %%
## Libraries
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import os

# %% [markdown]
# ### Invoke SageMaker predictive service

# %%
import boto3
import re
from sagemaker import get_execution_role
import sagemaker
# SageMaker SDK Documentation: http://sagemaker.readthedocs.io/en/latest/estimators.html

# %% [markdown]
# ## Upload data to S3

# %%
# Specify your bucket name
bucket_name = 'robiny-ml-sagemaker'

training_folder = r'rob-bikerental/training/'
validation_folder = r'rob-bikerental/validation/'
test_folder = r'rob-bikerental/test/'

s3_model_output_location = r's3://{0}/rob-bikerental/model'.format(bucket_name)
s3_training_file_location = r's3://{0}/{1}'.format(bucket_name, training_folder)
s3_validation_file_location = r's3://{0}/{1}'.format(bucket_name, validation_folder)
s3_test_file_location = r's3://{0}/{1}'.format(bucket_name, test_folder)

# %%
print(s3_model_output_location)
print(s3_training_file_location)
print(s3_validation_file_location)
print(s3_test_file_location)
# Out:
# s3://robiny-ml-sagemaker/rob-bikerental/model
# s3://robiny-ml-sagemaker/rob-bikerental/training/
# s3://robiny-ml-sagemaker/rob-bikerental/validation/
# s3://robiny-ml-sagemaker/rob-bikerental/test/

# %% [markdown]
# ### Write and Read file from S3

# %%
# Write and Reading from S3 is just as easy
# files are referred as objects in S3.  
# file name is referred as key name in S3

# File stored in S3 is automatically replicated across 3 different availability zones 
# in the region where the bucket was created.

# http://boto3.readthedocs.io/en/latest/guide/s3.html
def write_to_s3(filename, bucket, key):
    with open(filename,'rb') as f: # Read in binary mode
        return boto3.Session().resource('s3').Bucket(bucket).Object(key).upload_fileobj(f)

write_to_s3('rob_bike_train.csv', 
            bucket_name,
            training_folder + 'rob_bike_train.csv')

write_to_s3('rob_bike_validation.csv',
            bucket_name,
            validation_folder + 'rob_bike_validation.csv')

write_to_s3('rob_bike_test.csv',
            bucket_name,
            test_folder + 'rob_bike_test.csv')

# %% [markdown]
# ## Training Algorithm Docker Image
# ### SageMaker maintains a separate image for algorithm and region
# https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-algo-docker-registry-paths.html

# %%
# Establish a session with AWS
sess = sagemaker.Session()
role = get_execution_role()

# This role contains the permissions needed to train, deploy models
# SageMaker Service is trusted to assume this role
print(role)
# Out:
# arn:aws:iam::501191679407:role/service-role/AmazonSageMaker-ExecutionRole-20200530T140508

# %% [raw]
# In the past, we had to maintain the algorithm containers mapping:
#
#
# containers = {'us-west-2': '433757028032.dkr.ecr.us-west-2.amazonaws.com/xgboost:latest',
#               'us-east-1': '811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:latest',
#               'us-east-2': '825641698319.dkr.ecr.us-east-2.amazonaws.com/xgboost:latest',
#               'eu-west-1': '685385470294.dkr.ecr.eu-west-1.amazonaws.com/xgboost:latest'}
#
# Reference:
# https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-algo-docker-registry-paths.html

# %%
# Sagemaker API now maintains the algorithm container mapping for us
# Specify the region, algorithm and version
container = sagemaker.amazon.amazon_estimator.get_image_uri(
    sess.boto_region_name,
    "xgboost", 
    "latest")

print('Using SageMaker XGBoost container:\n{} ({})'.format(container, sess.boto_region_name))
# Out:
# WARNING:root:There is a more up to date SageMaker XGBoost image. To use the newer image, please set 'repo_version'='0.90-1'. For example:
# 	get_image_uri(region, 'xgboost', '0.90-1').
# Using SageMaker XGBoost container:
# 632365934929.dkr.ecr.us-west-1.amazonaws.com/xgboost:latest (us-west-1)

# %% [markdown]
# ## Build the model

# %%
# Configure the training job
# Specify type and number of instances to use
# S3 location where final artifacts needs to be stored

#   Reference: http://sagemaker.readthedocs.io/en/latest/estimators.html

estimator = sagemaker.estimator.Estimator(
    container,
    role, 
    train_instance_count=1, 
    train_instance_type='ml.m4.xlarge',
    output_path=s3_model_output_location,
    sagemaker_session=sess,
    base_job_name ='xgboost-bikerental')

# %%
# Specify hyper parameters that appropriate for the training algorithm
# XGBoost Training Parameter Reference: 
#   https://github.com/dmlc/xgboost/blob/master/doc/parameter.md

# max_depth=5,eta=0.1,subsample=0.7,num_round=150
estimator.set_hyperparameters(max_depth=5,
                              objective="reg:linear",
                              eta=0.1,
                              num_round=150)

# %% [markdown]
# ### Specify Training Data Location and Optionally, Validation Data Location

# %%
# content type can be libsvm or csv for XGBoost
training_input_config = sagemaker.session.s3_input(
    s3_data=s3_training_file_location,
    content_type='csv',
    s3_data_type='S3Prefix')

validation_input_config = sagemaker.session.s3_input(
    s3_data=s3_validation_file_location,
    content_type='csv',
    s3_data_type='S3Prefix'
)

data_channels = {'train': training_input_config, 'validation': validation_input_config}

print(training_input_config.config)
print(validation_input_config.config)
# Out:
# {'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix', 'S3Uri': 's3://robiny-ml-sagemaker/rob-bikerental/training/', 'S3DataDistributionType': 'FullyReplicated'}}, 'ContentType': 'csv'}
# {'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix', 'S3Uri': 's3://robiny-ml-sagemaker/rob-bikerental/validation/', 'S3DataDistributionType': 'FullyReplicated'}}, 'ContentType': 'csv'}

# %% [markdown]
# ## Train the model

# %%
# XGBoost supports "train", "validation" channels
# Reference: Supported channels by algorithm
#   https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-algo-docker-registry-paths.html
estimator.fit(data_channels)
# Out:
# 2020-06-02 19:34:17 Starting - Starting the training job...
# 2020-06-02 19:34:19 Starting - Launching requested ML instances......
# 2020-06-02 19:35:30 Starting - Preparing the instances for training......
# 2020-06-02 19:36:31 Downloading - Downloading input data...
# 2020-06-02 19:37:18 Training - Training image download completed. Training in progress.
# 2020-06-02 19:37:18 Uploading - Uploading generated training model.Arguments: train
# [2020-06-02:19:37:13:INFO] Running standalone xgboost training.
# [2020-06-02:19:37:13:INFO] File size need to be processed in the node: 0.65mb. Available memory size in the node: 8453.14mb
# [2020-06-02:19:37:13:INFO] Determined delimiter of CSV input is ','
# [19:37:13] S3DistributionType set as FullyReplicated
# [19:37:13] 7620x13 matrix with 99060 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2020-06-02:19:37:13:INFO] Determined delimiter of CSV input is ','
# [19:37:13] S3DistributionType set as FullyReplicated
# [19:37:13] 3266x13 matrix with 42458 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=5
# [0]#011train-rmse:3.90481#011validation-rmse:3.915
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=5
# [1]#011train-rmse:3.52571#011validation-rmse:3.53473
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# [2]#011train-rmse:3.18357#011validation-rmse:3.19135
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [3]#011train-rmse:2.87753#011validation-rmse:2.88396
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [4]#011train-rmse:2.60175#011validation-rmse:2.60792
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [5]#011train-rmse:2.35539#011validation-rmse:2.36057
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# [6]#011train-rmse:2.13328#011validation-rmse:2.13766
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [7]#011train-rmse:1.93436#011validation-rmse:1.93815
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [8]#011train-rmse:1.75541#011validation-rmse:1.75955
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [9]#011train-rmse:1.59684#011validation-rmse:1.60086
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [10]#011train-rmse:1.4523#011validation-rmse:1.45613
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [11]#011train-rmse:1.32451#011validation-rmse:1.32875
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [12]#011train-rmse:1.21094#011validation-rmse:1.21528
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [13]#011train-rmse:1.10819#011validation-rmse:1.1128
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [14]#011train-rmse:1.01308#011validation-rmse:1.01895
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [15]#011train-rmse:0.930727#011validation-rmse:0.936581
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [16]#011train-rmse:0.859048#011validation-rmse:0.86507
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
#
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [119]#011train-rmse:0.240248#011validation-rmse:0.289447
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [120]#011train-rmse:0.239964#011validation-rmse:0.289379
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [121]#011train-rmse:0.239508#011validation-rmse:0.28926
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=5
# [122]#011train-rmse:0.239288#011validation-rmse:0.28921
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=5
# [123]#011train-rmse:0.239146#011validation-rmse:0.289111
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [124]#011train-rmse:0.23864#011validation-rmse:0.288795
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=5
# [125]#011train-rmse:0.238174#011validation-rmse:0.28861
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=5
# [126]#011train-rmse:0.237956#011validation-rmse:0.288422
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [127]#011train-rmse:0.237445#011validation-rmse:0.28851
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# [128]#011train-rmse:0.23713#011validation-rmse:0.288454
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=5
# [129]#011train-rmse:0.23696#011validation-rmse:0.288389
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [130]#011train-rmse:0.23653#011validation-rmse:0.288203
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [131]#011train-rmse:0.236067#011validation-rmse:0.288095
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# [132]#011train-rmse:0.235798#011validation-rmse:0.288096
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [133]#011train-rmse:0.235283#011validation-rmse:0.287883
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [134]#011train-rmse:0.234849#011validation-rmse:0.287947
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [135]#011train-rmse:0.234621#011validation-rmse:0.28789
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=5
# [136]#011train-rmse:0.234471#011validation-rmse:0.287796
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=5
# [137]#011train-rmse:0.234296#011validation-rmse:0.287725
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=5
# [138]#011train-rmse:0.234167#011validation-rmse:0.287694
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# [139]#011train-rmse:0.234036#011validation-rmse:0.287661
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# [140]#011train-rmse:0.233799#011validation-rmse:0.287701
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [141]#011train-rmse:0.233351#011validation-rmse:0.287619
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=5
# [142]#011train-rmse:0.233271#011validation-rmse:0.287616
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [143]#011train-rmse:0.233156#011validation-rmse:0.287581
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=5
# [144]#011train-rmse:0.233068#011validation-rmse:0.287577
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# [145]#011train-rmse:0.232562#011validation-rmse:0.287295
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [146]#011train-rmse:0.232108#011validation-rmse:0.286998
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [147]#011train-rmse:0.231565#011validation-rmse:0.286905
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [148]#011train-rmse:0.231239#011validation-rmse:0.286819
# [19:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [149]#011train-rmse:0.231105#011validation-rmse:0.286812
# 2020-06-02 19:37:25 Completed - Training job completed
# Training seconds: 54
# Billable seconds: 54

# %% [markdown]
# ## Deploy the model

# %%
# Ref: http://sagemaker.readthedocs.io/en/latest/estimators.html
predictor = estimator.deploy(initial_instance_count=1,
                             instance_type='ml.m4.xlarge',
                             endpoint_name = 'xgboost-bikerental')
# Out:
# ---------------!

# %% [markdown]
# ## Run Predictions

# %%
from sagemaker.predictor import csv_serializer, json_deserializer

predictor.content_type = 'text/csv'
predictor.serializer = csv_serializer
predictor.deserializer = None

# %%
predictor.predict([[3,0,1,2,28.7,33.335,79,12.998,2011,7,7,3]])
# Out:
# b'3.77382278442'

# %% [markdown]
# ## Summary
# 1. Ensure Training, Test and Validation data are in S3 Bucket
# 2. Select Algorithm Container Registry Path - Path varies by region
# 3. Configure Estimator for training - Specify Algorithm container, instance count, instance type, model output location
# 4. Specify algorithm specific hyper parameters
# 5. Train model
# 6. Deploy model - Specify instance count, instance type and endpoint name
# 7. Run Predictions

# %% [markdown]
# <h1>XGBoost Amazon SageMaker Prediction </h1>

# %%
# Acquire a realtime endpoint
endpoint_name = 'xgboost-bikerental'
predictor = sagemaker.predictor.RealTimePredictor(endpoint=endpoint_name)

from sagemaker.predictor import csv_serializer, json_deserializer

predictor.content_type = 'text/csv'
predictor.serializer = csv_serializer
predictor.deserializer = None

# %%
df_all = pd.read_csv('rob_bike_test.csv')
display(df_all.head())
print(df_all.shape)
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1  2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2  2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3  2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4  2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed  year  month  day  dayofweek  hour
# 0        56    26.0027  2011      1   20          3     0
# 1        56     0.0000  2011      1   20          3     1
# 2        56     0.0000  2011      1   20          3     2
# 3        56    11.0014  2011      1   20          3     3
# 4        56    11.0014  2011      1   20          3     4
# (6493, 14)

# %%
## check columns header
print(df_all.columns.tolist())
print(df_all.columns[1:])
# Out:
# ['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed', 'year', 'month', 'day', 'dayofweek', 'hour']
# Index(['season', 'holiday', 'workingday', 'weather', 'temp', 'atemp',
#        'humidity', 'windspeed', 'year', 'month', 'day', 'dayofweek', 'hour'],
#       dtype='object')

# %%
# Need to pass an array to the prediction
# can pass a numpy array or a list of values [[19,1],[20,1]]
arr_test = df_all[df_all.columns[1:]].values
print(arr_test)

print("\nType of data", type(arr_test))
print("\nShape of data", arr_test.shape)
# Out:
# [[ 1.  0.  1. ... 20.  3.  0.]
#  [ 1.  0.  1. ... 20.  3.  1.]
#  [ 1.  0.  1. ... 20.  3.  2.]
#  ...
#  [ 1.  0.  1. ... 31.  0. 21.]
#  [ 1.  0.  1. ... 31.  0. 22.]
#  [ 1.  0.  1. ... 31.  0. 23.]]
#
# Type of data <class 'numpy.ndarray'>
#
# Shape of data (6493, 13)

# %%
arr_test[:5]
# Out:
# array([[1.00000e+00, 0.00000e+00, 1.00000e+00, 1.00000e+00, 1.06600e+01,
#         1.13650e+01, 5.60000e+01, 2.60027e+01, 2.01100e+03, 1.00000e+00,
#         2.00000e+01, 3.00000e+00, 0.00000e+00],
#        [1.00000e+00, 0.00000e+00, 1.00000e+00, 1.00000e+00, 1.06600e+01,
#         1.36350e+01, 5.60000e+01, 0.00000e+00, 2.01100e+03, 1.00000e+00,
#         2.00000e+01, 3.00000e+00, 1.00000e+00],
#        [1.00000e+00, 0.00000e+00, 1.00000e+00, 1.00000e+00, 1.06600e+01,
#         1.36350e+01, 5.60000e+01, 0.00000e+00, 2.01100e+03, 1.00000e+00,
#         2.00000e+01, 3.00000e+00, 2.00000e+00],
#        [1.00000e+00, 0.00000e+00, 1.00000e+00, 1.00000e+00, 1.06600e+01,
#         1.28800e+01, 5.60000e+01, 1.10014e+01, 2.01100e+03, 1.00000e+00,
#         2.00000e+01, 3.00000e+00, 3.00000e+00],
#        [1.00000e+00, 0.00000e+00, 1.00000e+00, 1.00000e+00, 1.06600e+01,
#         1.28800e+01, 5.60000e+01, 1.10014e+01, 2.01100e+03, 1.00000e+00,
#         2.00000e+01, 3.00000e+00, 4.00000e+00]])

# %%
## Prediction original test dataset
result = predictor.predict(arr_test[:2])
result
# Out:
# b'2.3321223259,1.90055930614'

# %%
# For large number of predictions, we can split the input data and
# Query the prediction service.
# array_split is convenient to specify how many splits are needed
predictions = []
for arr in np.array_split(arr_test,10):
    result = predictor.predict(arr)
    result = result.decode("utf-8")
    result = result.split(',')
    print (arr.shape)
    predictions += [float(r) for r in result]
# Out:
# (650, 13)
# (650, 13)
# (650, 13)
# (649, 13)
# (649, 13)
# (649, 13)
# (649, 13)
# (649, 13)
# (649, 13)
# (649, 13)

# %%
## Inverse the log transofrmation to get actual bike rental count
np.expm1(predictions)

df_all['count'] = np.expm1(predictions)
df_all.head()
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1  2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2  2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3  2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4  2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed  year  month  day  dayofweek  hour     count
# 0        56    26.0027  2011      1   20          3     0  9.299778
# 1        56     0.0000  2011      1   20          3     1  5.689635
# 2        56     0.0000  2011      1   20          3     2  4.112099
# 3        56    11.0014  2011      1   20          3     3  1.822707
# 4        56    11.0014  2011      1   20          3     4  1.604999

# %%
df_all[['datetime','count']].to_csv('predicted_count_cloud.csv',index=False)

# %%
check = pd.read_csv("predicted_count_cloud.csv")
check.head()
# Out:
#               datetime     count
# 0  2011-01-20 00:00:00  9.299778
# 1  2011-01-20 01:00:00  5.689635
# 2  2011-01-20 02:00:00  4.112099
# 3  2011-01-20 03:00:00  1.822707
# 4  2011-01-20 04:00:00  1.604999
